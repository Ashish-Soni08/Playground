# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashish-Soni08/100-Days-Of-Code/blob/main/Day_39_Playground_for_Diffusers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qqq diffusers transformers
# Out:
#      |████████████████████████████████| 95 kB 1.3 MB/s
#      |████████████████████████████████| 4.7 MB 39.9 MB/s
#      |████████████████████████████████| 101 kB 11.4 MB/s
#      |████████████████████████████████| 6.6 MB 46.8 MB/s
#      |████████████████████████████████| 596 kB 62.5 MB/s

# %%
from diffusers import DiffusionPipeline
# import torch

# device = "cuda" if torch.cuda.is_available() else "cpu"

# choose a model
model_id = "CompVis/ldm-text2im-large-256"

# load model and scheduler
ldm = DiffusionPipeline.from_pretrained(model_id)

# run inference (sample random noise and denoise)
prompt = "A painting of a squirrel eating a nut"

images = ldm([prompt], num_inference_steps=50, eta=.3, guidance_scale=6)
# Out:
# Downloading:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/118k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/108k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/98.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/80.8k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/376 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/252 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/420 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/713 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.49G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/522 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/335M [00:00<?, ?B/s]
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
images['sample'][0]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FD794B05C10>
